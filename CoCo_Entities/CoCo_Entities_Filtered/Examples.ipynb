# %% [markdown]
# # COCO Entities Demo

# %%
ann_paths = {
    "train": "/root/Documents/DATASETS/CoCo_Entities/CoCo_Entities_Filtered/annotations/coco_karpathy_train.json",
    "val": "/root/Documents/DATASETS/CoCo_Entities/CoCo_Entities_Filtered/annotations/coco_karpathy_val.json",
    "test": "/root/Documents/DATASETS/CoCo_Entities/CoCo_Entities_Filtered/annotations/coco_karpathy_test.json",
}

entities_paths = {
    "train": "/root/Documents/DATASETS/CoCo_Entities/CoCo_Entities_Filtered/entities/coco_entities_train.json",
    "val": "/root/Documents/DATASETS/CoCo_Entities/CoCo_Entities_Filtered/entities/coco_entities_val.json",
    "test": "/root/Documents/DATASETS/CoCo_Entities/CoCo_Entities_Filtered/entities/coco_entities_test.json",
}

vis_root = "/root/Documents/DATASETS/MS_COCO/images"

# %%
import os
from pprint import pprint

import json
def read_json(file_path):
    return json.load(open(file_path, "r"))

from PIL import Image
def read_image(image_path):
    return Image.open(image_path)

def get_subimage(image, x1, y1, x2, y2):
    # x1, y1: left_upper conner point
    # x2, y2: right_lower conner point
    return image.crop([x1, y1, x2, y2])

# %% [markdown]
# ## Train

# %%
coco_anns = read_json(ann_paths["train"])
coco_entities = read_json(entities_paths["train"])

# %% [markdown]
# ### Overview

# %%
# annotation
idx = 11
pprint(coco_anns[idx])
image = read_image(os.path.join(vis_root, coco_anns[idx]["image"]))
image
# Out:
# {'caption': 'Man in apron standing on front of oven with pans and bakeware',
#  'image': 'val2014/COCO_val2014_000000397133.jpg',
#  'image_id': 'coco_397133'}
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427>

# %% [markdown]
# Since there only 1 caption for each training image, there will only have 1 entity annotation.

# %%
# entities
print("Keys: ")
pprint(list(coco_entities[idx].keys()))

print("Values: ")
pprint(list(coco_entities[idx].values()))
# Out:
# Keys:
# ['Man in apron standing on front of oven with pans and bakeware']
# Values:
# [{'det_caption': 'man in apron standing on front of oven with pans and '
#                  'bakeware',
#   'det_sequences': ['man',
#                     None,
#                     '_',
#                     None,
#                     None,
#                     '_',
#                     None,
#                     'stove',
#                     None,
#                     'pans',
#                     None,
#                     'pans'],
#   'detections': {'man': [[15,
#                           [393.955078125,
#                            57.99053955078125,
#                            519.2340087890625,
#                            323.6405029296875]]],
#                  'pans': [[33,
#                            [253.7294921875,
#                             25.433135986328125,
#                             434.8190002441406,
#                             193.7801971435547]]],
#                  'stove': [[8,
#                             [481.3494567871094,
#                              196.17063903808594,
#                              627.3591918945312,
#                              351.0577697753906]],
#                            [19,
#                             [11.80087947845459,
#                              145.65744018554688,
#                              202.84828186035156,
#                              305.0623474121094]]]},
#   'noun_chunks': [['man', 'man'],
#                   ['apron', '_'],
#                   ['front', '_'],
#                   ['oven', 'stove'],
#                   ['pans', 'pans'],
#                   ['bakeware', 'pans']],
#   'split': 'train'}]

# %%
# statistics
from collections import defaultdict
entities_num_count = defaultdict(lambda:0) 
for idx in range(len(coco_entities)):
    entities_num_count[
        len(list(coco_entities[idx].values())[0]["detections"])] += 1
entities_num_count # or, detections num count
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {1: 136757,
#              2: 242910,
#              3: 135281,
#              5: 3876,
#              4: 25545,
#              6: 633,
#              0: 35,
#              7: 143,
#              8: 28,
#              9: 13,
#              10: 3})

# %% [markdown]
# ###  Read detection sequence

# %%
idx = 11
caption = coco_anns[idx]["caption"]
print(caption.split(" "))
print(coco_entities[idx][caption]["det_sequences"])
# Out:
# ['Man', 'in', 'apron', 'standing', 'on', 'front', 'of', 'oven', 'with', 'pans', 'and', 'bakeware']
# ['man', None, '_', None, None, '_', None, 'stove', None, 'pans', None, 'pans']

# %% [markdown]
# ### Read noun chunks & entities

# %%
caption = coco_anns[idx]["caption"]
noun_chunks = coco_entities[idx][caption]['noun_chunks']

print("caption:", caption)
print('noun chunks:')
for i, nc in enumerate(noun_chunks):
    print('- %s (det. class: %s)' % (nc[0], nc[1]))
# Out:
# caption: Man in apron standing on front of oven with pans and bakeware
# noun chunks:
# - man (det. class: man)
# - apron (det. class: _)
# - front (det. class: _)
# - oven (det. class: stove)
# - pans (det. class: pans)
# - bakeware (det. class: pans)

# %% [markdown]
# ### Read BBOX

# %% [markdown]
# there may be multi bboxes for a entity:

# %%
det_classes = coco_entities[idx][caption]["detections"]
for cls in det_classes:
    print("%s:" % cls)
    for det in det_classes[cls]:
        det_id = det[0]
        bbox = det[1]
        print(" - det. id: %s, bbox: %s" % (det_id, bbox))
# Out:
# stove:
#  - det. id: 8, bbox: [481.3494567871094, 196.17063903808594, 627.3591918945312, 351.0577697753906]
#  - det. id: 19, bbox: [11.80087947845459, 145.65744018554688, 202.84828186035156, 305.0623474121094]
# pans:
#  - det. id: 33, bbox: [253.7294921875, 25.433135986328125, 434.8190002441406, 193.7801971435547]
# man:
#  - det. id: 15, bbox: [393.955078125, 57.99053955078125, 519.2340087890625, 323.6405029296875]

# %% [markdown]
# the bbox compose of the left_upper point and right_lower point : `[x1, y1, x2, y2]`
#
# here is how to get a subimage for a entity:

# %%
entity = "stove"
bbox_id = 1

bbox = coco_entities[idx][caption]["detections"][entity][bbox_id][1]
image = read_image(os.path.join(vis_root, coco_anns[idx]["image"]))
subimage = get_subimage(image, *bbox)
print(bbox)
subimage
# Out:
# [11.80087947845459, 145.65744018554688, 202.84828186035156, 305.0623474121094]
# <PIL.Image.Image image mode=RGB size=191x159>

# %% [markdown]
# ###  Visualize detections¶

# %%
import matplotlib.pyplot as plt
import cv2
import os

def visualize_detections(idx, coco_anns, coco_entities):
    img = cv2.imread(os.path.join(vis_root, coco_anns[idx]["image"]))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)

    caption = coco_anns[idx]["caption"]
    if type(caption) is list:
        caption = caption[0]
    for cls in coco_entities[idx][caption]['detections']:
        for det in coco_entities[idx][caption]['detections'][cls]:
            bbox = det[1]
            if bbox[0] == 0:
                bbox[0] = 1
            if bbox[1] == 0:
                bbox[1] = 1
            plt.gca().add_patch(plt.Rectangle((bbox[0], bbox[1]), bbox[2] - bbox[0], bbox[3] - bbox[1], 
                                              fill=False, edgecolor='red', linewidth=2, alpha=0.5))
            plt.gca().text(bbox[0], bbox[1] - 2, '%s' % (cls), bbox=dict(facecolor='blue', alpha=0.5), 
                           fontsize=10, color='white')

# %%
visualize_detections(11, coco_anns, coco_entities)

# %% [markdown]
# ## Valid / Test

# %% [markdown]
# notice that there will multi annotations (& entities annotations) for val / test set

# %%
coco_anns = read_json(ann_paths["test"])
coco_entities = read_json(entities_paths["test"])

# %%
visualize_detections(0, coco_anns, coco_entities)

# %% [markdown]
# ### Overview

# %%
# annotation
idx = 11
pprint(coco_anns[idx])
image = read_image(os.path.join(vis_root, coco_anns[idx]["image"]))
image
# Out:
# {'caption': ['A row of motorcycles parked in front of a building.',
#              'A bunch of motorcycles parked on the side of the road',
#              'a back ally neighborhood with motor bikes in a row',
#              'A number of motorbikes parked on an alley',
#              'a bunch of motorcycles parked along the side of the street '],
#  'image': 'val2014/COCO_val2014_000000394240.jpg'}
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427>

# %%
# entities
print("Keys: ")
pprint(list(coco_entities[idx].keys()))

print("\nValues: ")
pprint(list(coco_entities[idx].values()))
# Out:
# Keys:
# ['A row of motorcycles parked in front of a building.',
#  'A bunch of motorcycles parked on the side of the road',
#  'a back ally neighborhood with motor bikes in a row',
#  'A number of motorbikes parked on an alley',
#  'a bunch of motorcycles parked along the side of the street ']
#
# Values:
# [{'det_caption': 'a row of motorcycles parked in front of a building',
#   'det_sequences': ['_',
#                     '_',
#                     None,
#                     'motorcycle',
#                     None,
#                     None,
#                     '_',
#                     None,
#                     'building',
#                     'building'],
#   'detections': {'building': [[1,
#                                [321.3691101074219,
#                                 0.0,
#                                 639.07666015625,
#                                 367.59930419921875]],
#                               [2,
#                                [40.52293395996094,
#                                 0.0,
#                                 242.4770050048828,
#                                 400.5038146972656]],
#                               [3,
#                                [0.0,
#                                 0.0,
#                                 451.36639404296875,
#                                 247.44805908203125]],
#                               [26,
#                                [224.09913635253906,
#                                 24.931550979614258,
#                                 326.36474609375,
#                                 250.6583251953125]]],
#                  'motorcycle': [[0,
#                                  [246.69190979003906,
#                                   154.17880249023438,
#                                   639.07666015625,
#                                   426.288330078125]],
#                                 [11,
#                                  [234.4650421142578,
#                                   311.41680908203125,
#                                   512.3524169921875,
#                                   426.288330078125]],
#                                 [22,
#                                  [317.8189392089844,
#                                   245.6129913330078,
#                                   433.0702819824219,
#                                   299.3125305175781]],
#                                 [24,
#                                  [268.6895751953125,
#                                   238.6238250732422,
#                                   534.2583618164062,
#                                   352.33953857421875]]]},
#   'noun_chunks': [['a row', '_'],
#                   ['motorcycles', 'motorcycle'],
#                   ['front', '_'],
#                   ['a building', 'building']],
#   'split': 'test'},
#  {'det_caption': 'a bunch of motorcycles parked on the side of the road',
#   'det_sequences': ['_',
#                     '_',
#                     None,
#                     'motorcycle',
#                     None,
#                     None,
#                     '_',
#                     '_',
#                     None,
#                     '_',
#                     '_'],
#   'detections': {'motorcycle': [[0,
#                                  [246.69190979003906,
#                                   154.17880249023438,
#                                   639.07666015625,
#                                   426.288330078125]],
#                                 [11,
#                                  [234.4650421142578,
#                                   311.41680908203125,
#                                   512.3524169921875,
#                                   426.288330078125]],
#                                 [22,
#                                  [317.8189392089844,
#                                   245.6129913330078,
#                                   433.0702819824219,
#                                   299.3125305175781]],
#                                 [24,
#                                  [268.6895751953125,
#                                   238.6238250732422,
#                                   534.2583618164062,
#                                   352.33953857421875]]]},
#   'noun_chunks': [['a bunch', '_'],
#                   ['motorcycles', 'motorcycle'],
#                   ['the side', '_'],
#                   ['the road', '_']],
#   'split': 'test'},
#  {'det_caption': 'a back ally neighborhood with motor bikes in a row',
#   'det_sequences': ['street',
#                     'street',
#                     'street',
#                     'street',
#                     None,
#                     '_',
#                     '_',
#                     None,
#                     '_',
#                     '_'],
#   'detections': {'street': [[4,
#                              [46.359737396240234,
#                               198.9544219970703,
#                               588.5520629882812,
#                               426.288330078125]],
#                             [17,
#                              [122.27943420410156,
#                               289.1717529296875,
#                               476.85601806640625,
#                               426.288330078125]],
#                             [27,
#                              [134.79542541503906,
#                               268.9431457519531,
#                               317.718994140625,
#                               426.288330078125]]]},
#   'noun_chunks': [['a back ally neighborhood', 'street'],
#                   ['motor bikes', '_'],
#                   ['a row', '_']],
#   'split': 'test'},
#  {'det_caption': 'a number of motorbikes parked on an alley',
#   'det_sequences': ['_',
#                     '_',
#                     None,
#                     'motorcycle',
#                     None,
#                     None,
#                     'sidewalk',
#                     'sidewalk'],
#   'detections': {'motorcycle': [[0,
#                                  [246.69190979003906,
#                                   154.17880249023438,
#                                   639.07666015625,
#                                   426.288330078125]],
#                                 [11,
#                                  [234.4650421142578,
#                                   311.41680908203125,
#                                   512.3524169921875,
#                                   426.288330078125]],
#                                 [22,
#                                  [317.8189392089844,
#                                   245.6129913330078,
#                                   433.0702819824219,
#                                   299.3125305175781]],
#                                 [24,
#                                  [268.6895751953125,
#                                   238.6238250732422,
#                                   534.2583618164062,
#                                   352.33953857421875]]],
#                  'sidewalk': [[7,
#                                [49.80387496948242,
#                                 254.9326934814453,
#                                 320.80340576171875,
#                                 409.4378662109375]]]},
#   'noun_chunks': [['a number', '_'],
#                   ['motorbikes', 'motorcycle'],
#                   ['an alley', 'sidewalk']],
#   'split': 'test'},
#  {'det_caption': 'a bunch of motorcycles parked along the side of the street',
#   'det_sequences': ['_',
#                     '_',
#                     None,
#                     'motorcycle',
#                     None,
#                     None,
#                     '_',
#                     '_',
#                     None,
#                     'street',
#                     'street'],
#   'detections': {'motorcycle': [[0,
#                                  [246.69190979003906,
#                                   154.17880249023438,
#                                   639.07666015625,
#                                   426.288330078125]],
#                                 [11,
#                                  [234.4650421142578,
#                                   311.41680908203125,
#                                   512.3524169921875,
#                                   426.288330078125]],
#                                 [22,
#                                  [317.8189392089844,
#                                   245.6129913330078,
#                                   433.0702819824219,
#                                   299.3125305175781]],
#                                 [24,
#                                  [268.6895751953125,
#                                   238.6238250732422,
#                                   534.2583618164062,
#                                   352.33953857421875]]],
#                  'street': [[4,
#                              [46.359737396240234,
#                               198.9544219970703,
#                               588.5520629882812,
#                               426.288330078125]],
#                             [17,
#                              [122.27943420410156,
#                               289.1717529296875,
#                               476.85601806640625,
#                               426.288330078125]],
#                             [27,
#                              [134.79542541503906,
#                               268.9431457519531,
#                               317.718994140625,
#                               426.288330078125]]]},
#   'noun_chunks': [['a bunch', '_'],
#                   ['motorcycles', 'motorcycle'],
#                   ['the side', '_'],
#                   ['the street', 'street']],
#   'split': 'test'}]
